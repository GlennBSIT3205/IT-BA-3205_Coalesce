# %% [markdown]
# <a href="https://colab.research.google.com/github/GlennBSIT3205/IT-BA-3205_Coalesce/blob/main/Education%20in%20the%20Philippines%20Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Number of Enrolled and Graduates by different Courses (2016-2019)**
#
#   There are 21 discipline groups, and the overall number of enrolled and graduates from 2016 to 2019 is shown. We can distinguish which courses have the highest and lowest number by analyzing the data.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Enrollment%26Graduates%20by%20Discipline.csv'
pd.options.display.max_rows = 30
df = pd.read_csv(url)
display(df)
# Out:
#                                 Unnamed: 0 Enrollment Unnamed: 2 Unnamed: 3  \
# 0                         Discipline Group    2016-17    2017-18    2018-19
# 1         Agriculture, Forestry, Fisheries    127,287    100,922    106,006
# 2           Architecture and Town Planning     40,238     33,439     40,163
# 3      Business Administration and Related    921,324    775,805    826,494
# 4   Education Science and Teacher Training    740,713    639,063    653,207
# 5                     Engineering and Tech    448,550    370,710    424,269
# 6                    Fine and Applied Arts     16,324     16,355     23,782
# 7                                  General      7,614      4,869      4,847
# 8                           Home Economics      5,960      4,876      4,324
# 9                               Humanities     40,753     36,332     37,246
# 10                  IT-Related Disciplines    398,765    315,694    314,414
# ...

# %% [markdown]
# ### **Discipline with Lowest and Highest Number of Enrolled and Graduates**
#
# In 2016-2019, the discipline has the lowest number of enrollees and graduates is the Trade, Craft and Industrial, while Business Administration and Related has the highest number of enrollees and graduates. Blue indicate as lowest enrolled, orange as highest enrolled, green as lowest graduates, and red as highest graduates. Blue and green are in the same spot.

# %%
w=0.2
Year = ["2016-2017","2017-2018","2018-2019"]
Lowest  =[411,218,151]
Highest = [921324,775805,826494]
GradL =[93,	75,	103]
GradH =[202895,	207178,	233194]
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)


plt.scatter(Year,Lowest, label='LEnrollees (Trade,..)')
plt.scatter(Year,Highest, label='HEnrollees (Business Ad)')


plt.scatter(Year,GradL, label='LGraduates (Trade,..)',marker = 'o')
plt.scatter(Year,GradH, label='HGraduates (Business Ad)')

plt.xlabel("Year")
plt.ylabel("Number of Enrolled and Graduates")

plt.title("\n Discipline with Lowest and Highest number of Enrolled and Graduates", fontsize=20, fontweight="bold")

plt.legend()
plt.show()

# %% [markdown]
# # **Enrolled and Graduates in State Universities and Colleges by Region**
#
# ## **Total of Enrolled and Graduates in all Region**

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Total%20Per%20Region%20-%20Sheet1.csv'
df = pd.read_csv(url)
display(df.iloc[0:19])
# Out:
#                            Region  Enrollment Unnamed: 2 Unnamed: 3 Graduates  \
# 0                              NaN    2017-18    2018-19    2019-20   2016-17
# 1                    Ilocos Region      56437     56,164     62,021    16,070
# 2                   Cagayan Valley     59,456     57,593     65,840    14,828
# 3                    Central Luzon    123,615    140,948    152,166    34,424
# 4                       CALABARZON    108,368    128,410    126,924    26,810
# 5                     Bicol Region     61,422     64,229     66,088    21,020
# 6                  Western Visayas     92,075    102,230    103,928    24,046
# 7                  Central Visayas     82,025     90,364     91,064    23,841
# 8                  Eastern Visayas     86,557     96,038     95,989    19,404
# 9              Zamboanga Peninsula     64,074     83,693     75,059    13,164
# 10               Northern Mindanao     43,825     48,557     52,469    11,055
# ...

# %% [markdown]
# ## **Number of State Universities and Colleges (SUCs) per Region**

# %%
#xvalues
w=20
Region = ["I","II","III", "IV-A", "V", "VI", "VII", "VIII", "IX", "X", "XI", "XII", "NCR", "CAR", "BARMM", "XIII", "IV-B"]
Number  =[6, 5, 12, 5, 9, 11, 5, 10, 6, 7, 5, 4, 8, 6, 5, 4, 6 ]



f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.xlabel("Region")
plt.ylabel("Number of School")

plt.title("\n Number of State Universities and Colleges (SUCs) per Region", fontsize=20, fontweight="bold")
plt.bar(Region,Number )
plt.show()

# %% [markdown]
# ## **Region with Lowest and Highest number of Enrolled and Graduates**
#
# In 2017-2019, the region has the lowest number of enrollees and graduates is the CAR while NCR has the highest number of enrollees and graduates. Blue indicate as lowest enrolled, orange as highest enrolled, green as lowest graduates, and red as highest graduates.

# %%
w=0.2
Year = ["2017-2018","2018-2019"]
Lowest  =[24788	, 26942]
Highest = [189139	, 203292]
GradL =[6217 , 5941]
GradH =[49501 ,	53585]
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)


plt.scatter(Year,Lowest, label='LEnrollees (CAR)')
plt.scatter(Year,Highest, label='HEnrollees (NCR)')


plt.scatter(Year,GradL, label='LGraduates (CAR)',marker = 'o')
plt.scatter(Year,GradH, label='HGraduates (NCR)')

plt.xlabel("Year")
plt.ylabel("Number of Enrolled and Graduates")

plt.title("\n Region with Lowest and Highest number of Enrolled and Graduates", fontsize=20, fontweight="bold")

plt.legend()
plt.show()

# %% [markdown]
# ## **Ilocos Region**
#   The Ilocos Region has six state universities and colleges, and this data shows the number of students enrolled and graduates from 2017 to 2019. Every year, we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[0:8])
# Out:
#   Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 0                                             Region
# 1                                                NaN
# 2                                      Ilocos Region
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                      Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                      SUC Name         NaN  Enrollment
# 1                                           NaN         NaN     2017-18
# 2  Don Mariano Marcos Memorial State University         NaN      13,320
# 3          Ilocos Sur Polytechnic State College         NaN       4,782
# 4               Mariano Marcos State University         NaN       8,247
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([56437, 56164	,62021 ])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([16070	, 16441 , 17915])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Ilocos Region", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Cagayan Valley**
# The Cagayan Valley has five state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[8:13])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 8                                      Cagayan Valley
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#                         Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 8            Batanes State College         NaN        268        698
# 9         Cagayan State University         NaN     25,056     21,914
# 10        Isabela State University         NaN     22,371     22,038
# 11  Nueva Vizcaya State University         NaN      8,135      9,143
# 12        Quirino State University         NaN      3,626      3,800
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 8         393         44         44        108         NaN
# 9      22,855      5,077      4,384      5,696         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([59456, 57593, 65840])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([14828	,12437 ,15463 ])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Cagayan Valley", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Central Luzon**
#
# The Central Luzon has twelve state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[13:25])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 13                                      Central Luzon
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 13                 Aurora State College of Technology         NaN      1,682
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([123615,140948,152166	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([34424	, 33335	, 38136])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Central Luzon", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **CALABARZON**
# The Calabarzon has five state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[25:30])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 25                                         CALABARZON
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                              Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 25            Batangas State University         NaN     27,246     40,431
# 26              Cavite State University         NaN     32,693     40,819
# 27  Laguna State Polytechnic University         NaN     21,326     23,040
# 28      Southern Luzon State University         NaN     11,465      8,309
# 29           University of Rizal System         NaN     15,638     15,811
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 25     33,076      5,159      9,542      7,312         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([108368, 128410	,126924 ])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([26810	,32049 , 32769])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("CALABARZON", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Bicol Region**
# The Bicol Region has nine state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[30:39])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 30                                       Bicol Region
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 30  Bicol State College of Applied Sciences and Te...         NaN      4,176
# 31                                   Bicol University         NaN     16,277
# 32                      Camarines Norte State College         NaN      5,280
# 33                 Camarines Sur Polytechnic Colleges         NaN      3,554
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([61422, 64229	,66088 ])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([21020	,22593 , 22231])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Bicol Region", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Western Visayas**
# The Western Visayas has eleven state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[39:50])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 39                                    Western Visayas
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 39                             Aklan State University         NaN      6,165
# 40                             Capiz State University         NaN     10,628
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([92075, 102230	,103928 ])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([24046	,26382 , 29862])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Western Visayas", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Central Visayas**
# The Central Visayas has five state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[50:55])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 50                                    Central Visayas
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                           Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 50     Bohol Island State University         NaN     13,784     16,170
# 51            Cebu Normal University         NaN      7,165      6,913
# 52     Cebu Technological University         NaN     35,926     39,398
# 53  Negros Oriental State University         NaN     23,887     26,411
# 54            Siquijor State College         NaN      1,263      1,472
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 50     15,417      3,342      4,185      4,287         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([82025, 90364, 91064])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([23841, 25978, 27615])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Central Visayas", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Eastern Visayas**
# The Easthern Visayas has ten state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[55:65])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 55                                    Eastern Visayas
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#                            Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 55     Eastern Samar State University         NaN     11,989     13,068
# 56   Eastern Visayas State University         NaN     16,369     19,462
# 57            Leyte Normal University         NaN      4,937      5,951
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([86557, 96038, 95989])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([19404, 22612, 23636])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Eastern Visayas", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Zamboanga Peninsula**
# The Zamboanga Peninsula has six state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[65:71])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 65                                Zamboanga Peninsula
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 65                              Basilan State College         NaN      3,769
# 66               Jose Rizal Memorial State University         NaN     12,226
# 67                 Josefina H. Cerilles State College         NaN     11,185
# 68                  Western Mindanao State University         NaN     26,664
# 69           Zamboanga City State Polytechnic College         NaN      5,776
# 70  Zamboanga State College of Marine Sciences and...         NaN      4,454
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([64074, 83693, 75059])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([13164, 16644, 13046])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Zamboanga Peninsula", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ### **Northern Mindanao**
# The Northern Mindanao has seven state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[71:78])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 71                                  Northern Mindanao
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 71                          Bukidnon State University         NaN     11,975
# 72                 Camiguin Polytechnic State College         NaN      2,053
# 73                        Central Mindanao University         NaN      7,480
# 74  Mindanao State University - Iligan Institute o...         NaN     10,274
# 75  Northwestern Mindanao State College of Science...         NaN      1,326
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([43825, 48557, 52469])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([11055, 11782, 12829])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Northern Mindanao", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Davao Region**
# The Davao Region has five state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[78:83])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 78                                       Davao Region
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 78                    Compostela Valley State College         NaN      4,291
# 79                      Davao del Norte State College         NaN      1,827
# 80  Davao Oriental State College of Science and Te...         NaN      9,143
# 81  Southern Philippines Agri-business and Marine ...         NaN      3,103
# 82             University of Southeastern Philippines         NaN     13,154
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 78      4,850      5,703          -        998        867         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([31518,33143,32031	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([7482	, 9254	, 8109])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Davao Region", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Soccskargen**
# The Soccskargen has four state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[83:87])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 83                                       Soccsksargen
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 83            Cotabato City State Polytechnic College         NaN      7,471
# 84  Cotabato Foundation College of Science and Tec...         NaN      5,511
# 85                    Sultan Kudarat State University         NaN     11,487
# 86                    University of Southern Mindanao         NaN     11,508
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 83      7,329      6,489      2,046      1,980      2,055         NaN
# 84      3,454      3,456      1,115        892        971         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([35977,34658,32613	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([9524	, 9587	, 9587])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Soccskargen", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **National Capital Region**
# The National Capital Region has eight state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[87:95])
# Out:
#    Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 87                            National Capital Region
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 87  Eulogio "Amang" Rodriguez Institute of Science...         NaN     22,011
# 88                       Marikina Polytechnic College         NaN      4,867
# 89                       Philippine Normal University         NaN      6,544
# 90            Philippine State College of Aeronautics         NaN      9,490
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([189139,203292,197866	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([46598	, 49501	, 53585])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("National Capital Region", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4) 
plt.show()

# %% [markdown]
# ## **Cordillera Administrative Region**
# The Cordillera Administrative Region has six state universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see a comparison of the number of students enrolled and graduates,and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[95:101])
# Out:
#     Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 95                      Cordillera Administrative Regi
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
#
#                                          Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 95   Abra State Institute of Science and Technology         NaN      2,723
# 96                             Apayao State College         NaN      2,080
# 97                         Benguet State University         NaN      7,548
# 98                          Ifugao State University         NaN      4,639
# 99                         Kalinga State University         NaN      4,186
# 100     Mountain Province State Polytechnic College         NaN      3,612
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([24788,26942,27899	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([6568	, 6217	, 5941])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Cordillera Administrative Region", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **BARMM**
# The BARMM has five universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[101:106])
# Out:
#     Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 101                                              BARMM
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
#
#                                             Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 101          Adiong Memorial Polytechnic State College         NaN      3,142
# 102                          Mindanao State University         NaN     31,980
# 103  Mindanao State University-Tawi-Tawi College of...         NaN      3,075
# 104                                 Sulu State College         NaN      5,196
# 105            Tawi-Tawi Regional Agricultural College         NaN      3,825
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([47218,43424,39900	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([8481	, 7283	, 7542])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("BARMM", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **Caraga**
# The Caraga has four universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[106:110])
# Out:
#     Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 106                                             Caraga
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
#
#                                             Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 106  Agusan del Sur State College of Agriculture an...         NaN      3,582
# 107                            Caraga State University         NaN      5,587
# 108                   Surigao del Sur State University         NaN      9,483
# 109                Surigao State College of Technology         NaN      9,632
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 106      4,225      5,594        532      1,153      1,177         NaN
# 107      7,101      8,448      1,105      1,372        591         NaN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([28284,32933,38313	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([5875	, 7708	, 7307])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("Caraga", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# ## **MIMAROPA**
# The MIMAROPA has six universities and colleges, and this data shows the number of enrolled and graduates from 2017-2019. Every year we can see comparison of the number of students enrolled and graduates, and we can tell which school has the most and least students.

# %%
url = 'https://raw.githubusercontent.com/GlennBSIT3205/IT-BA-3205_Coalesce/main/Data%20Sets/Higher-Education-Enrollment-and-Graduates-in-State-Universities-and-Colleges-1-converted.csv'
df = pd.read_csv(url)
display(df.iloc[110:116])
# Out:
#     Table 3A. Higher Education Enrollment and Graduates in State Universities and Colleges  \
# 110                                           MIMAROPA
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
#                                             Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 110                           Marinduque State College         NaN      4,703
# 111  Mindoro State College of Agriculture and Techn...         NaN      4,731
# 112                   Occidental Mindoro State College         NaN      7,044
# 113                           Palawan State University         NaN     16,387
# 114                           Romblon State University         NaN      8,167
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array(["2017-18", "2018-19", "2019-20"])
y = np.array([46425,60943,61603	])
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Enrollees")
plt.title("ENROLLED")
#plot 2:
x= np.array(["2016-17", "2017-18", "2018-19"])
y = np.array([13479	, 15354	, 14469])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Total Number of Graduates")
plt.title("GRADUATES")
plt.suptitle("MIMAROPA", fontsize =20,fontweight ='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()
